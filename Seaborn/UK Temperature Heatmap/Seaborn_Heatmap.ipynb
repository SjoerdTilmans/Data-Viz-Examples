# %%
import pandas as pd
import seaborn

# %%
df = pd.read_excel("Annual Temperatures UK.xlsx", index_col=0)

# %%
df
# Out:
#       Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1884        8.48        7.36        7.45        7.51        7.28        8.02
# 1896        8.26        8.23        8.88        8.57        8.28        8.08
# 1908        8.31        7.52        8.09        8.81        8.17        8.59
# 1920        8.45        9.24        7.63        7.97        8.19        8.12
# 1932        8.35        8.82        8.87        8.52        8.26        8.33
# 1944        8.44        9.13        8.35        8.37        8.81        9.34
# 1956        7.90        8.84        8.25        9.24        8.54        8.67
# 1968        8.16        8.12        8.31        8.73        8.10        8.43
# 1980        8.26        8.10        8.66        8.83        8.57        7.78
# 1992        8.69        8.33        8.89        9.17        8.18        9.41
# 2004        9.44        9.42        9.70        9.56        9.02        9.14
# ...

# %%
seaborn.heatmap(df, cmap="coolwarm", xticklabels=[], cbar_kws={"label": "Temperature [°C]"}).set_title("Average Annual Temperature in the UK, 1884 - 2021")
# Out:
# Text(0.5, 1.0, 'Average Annual Temperature in the UK, 1884 - 2021')
